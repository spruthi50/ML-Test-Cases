# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '2014_-_2015_School_Budget_Overview.csv',
#  'Logistic.ipynb']

# %%
#importing data
import pandas as pd
import numpy as np
dataset=pd.read_csv('2014_-_2015_School_Budget_Overview.csv')
dataset.info()
dataset.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1577 entries, 0 to 1576
# Data columns (total 21 columns):
# Fiscal_Year                           1577 non-null int64
# Location                              1577 non-null object
# S1: Label a: FY14 Revised Base        1577 non-null float64
# S1: Label b: FSF & TL 09 C4E CTT      1577 non-null float64
# S1: Label c: FSF Over Formula         1577 non-null float64
# S2: Label d: FSF Preliminary          1577 non-null float64
# S2: Label a: FY14 Revised Base        1577 non-null float64
# S2: Label f: Register Change          1577 non-null float64
# S2: Label g: Teacher Salary Growth    1577 non-null float64
# S2: Label h: New School Foundation    1577 non-null float64
# S3: Label i: FY14 FSF at 100%         1577 non-null float64
# S3: Foundation                        1577 non-null float64
# S3: Label d - Foundation              1577 non-null float64
# S3: Label i - Foundation              1577 non-null float64
# ...

# %%
dataset.rename(columns={"S1: Label a: FY14 Revised Base":"Revised Base"})
# Out:
#       Fiscal_Year Location  S1: Label a: FY14 Revised Base   \
# 0            2015     K001                        5957603.0
# 1            2015     K002                        2565500.0
# 2            2015     K003                        2364807.0
# 3            2015     K005                        1711158.0
# 4            2015     K006                        3771012.0
# ...           ...      ...                              ...
# 1572         2015     Q332                              0.0
# 1573         2015     Q313                              0.0
# 1574         2015     Q300                              0.0
# 1575         2015     R010                              0.0
# 1576         2015     R028                              0.0
#
#       S1: Label b: FSF & TL 09 C4E CTT   S1: Label c: FSF Over Formula  \
# 0                             5957603.0                            0.0
# 1                             2565500.0                            0.0
# ...

# %%
x=dataset.iloc[:,[1,2]].values
x
y=dataset.iloc[:,[8]].values
y
# Out:
# array([[0.],
#        [0.],
#        [0.],
#        ...,
#        [0.],
#        [0.],
#        [0.]])

# %%
#preprocessing
from sklearn.preprocessing import FunctionTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import Imputer
from sklearn.pipeline import FeatureUnion
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=.2,random_state=0)


text_data=FunctionTransformer(lambda X:X_train['text_data'],validate=False)

numeric_data=FunctionTransformer(lambda X:y_train['numeric_data'],validate=False)

joinFeature=FeatureUnion(transformer_list=[
    ('numeric_features',Pipeline
     (
         [
             ('selector',numeric_data),
             ('imputer',Imputer())
         ]
     )
    )
    ,
    ('text_features',Pipeline
     (
         [
             ('selector',text_data),
             ('vectorizer',CountVectorizer())
         ]
     )
    )
    
]
                        )
# Out:
# c:\users\sachin\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\utils\deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
pl=Pipeline([('union',joinFeature),
             ('clf',LogisticRegression())])
pl.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-49-8e1547d16322> in <module>
#       1 pl=Pipeline([('union',joinFeature),
#       2              ('clf',LogisticRegression())])
# ----> 3 pl.fit(X_train,y_train)
#
# c:\users\sachin\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\pipeline.py in fit(self, X, y, **fit_params)
#     350             This estimator
#     351         """
# --> 352         Xt, fit_params = self._fit(X, y, **fit_params)
#     353         with _print_elapsed_time('Pipeline',
#     354                                  self._log_message(len(self.steps) - 1)):
#
# c:\users\sachin\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\pipeline.py in _fit(self, X, y, **fit_params)
#     315                 message_clsname='Pipeline',
#     316                 message=self._log_message(step_idx),
# ...
