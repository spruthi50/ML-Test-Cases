# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '2014_-_2015_School_Budget_Overview.csv',
#  'Logistic.ipynb',
#  'Untitled.ipynb']

# %%
import pandas as pd
import numpy as np
dataset=pd.read_csv('2014_-_2015_School_Budget_Overview.csv')

# %%
dataset.head()
# Out:
#    Fiscal_Year Location  S1: Label a: FY14 Revised Base   \
# 0         2015     K001                          5957603
# 1         2015     K002                          2565500
# 2         2015     K003                          2364807
# 3         2015     K005                          1711158
# 4         2015     K006                          3771012
#
#    S1: Label b: FSF & TL 09 C4E CTT   S1: Label c: FSF Over Formula  \
# 0                            5957603                              0
# 1                            2565500                              0
# 2                            2364807                              0
# 3                            1711158                              0
# 4                            3771012                              0
#
#    S2: Label d: FSF Preliminary  S2: Label a: FY14 Revised Base  \
# 0                    5858476.18                         5957603
# 1                    2514000.62                         2565500
# ...

# %%
selected=dataset.iloc[:,[1,2,5,3]].values
print(selected)
print(selected[1])

dataset['Location'].dtype
dataset['S1: Label c: FSF Over Formula'].dtype
print(dataset['Location'].dtype)
# Out:
# [['K001' 5957603 5858476.18 5957603]
#  ['K002' 2565500 2514000.62 2565500]
#  ['K003' 2364807 2176535.16 2364807]
#  ...
#  ['Q300' 0 961975.69 0]
#  ['R010' 0 562635.91 0]
#  ['R028' 0 706573.46 0]]
# ['K002' 2565500 2514000.62 2565500]
# object

# %%
dataset.info()
x=dataset['Location'].nunique()
type(x)
z=dataset['S2: Label g: Teacher Salary Growth'].nunique()
type(z)
dataset['S2: Label g: Teacher Salary Growth'].dtype
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1577 entries, 0 to 1576
# Data columns (total 21 columns):
# Fiscal_Year                           1577 non-null int64
# Location                              1577 non-null object
# S1: Label a: FY14 Revised Base        1577 non-null int64
# S1: Label b: FSF & TL 09 C4E CTT      1577 non-null int64
# S1: Label c: FSF Over Formula         1577 non-null int64
# S2: Label d: FSF Preliminary          1577 non-null float64
# S2: Label a: FY14 Revised Base        1577 non-null int64
# S2: Label f: Register Change          1577 non-null float64
# S2: Label g: Teacher Salary Growth    1577 non-null int64
# S2: Label h: New School Foundation    1577 non-null int64
# S3: Label i: FY14 FSF at 100%         1577 non-null float64
# S3: Foundation                        1577 non-null int64
# S3: Label d - Foundation              1577 non-null float64
# S3: Label i - Foundation              1577 non-null float64
# ...

# %%
 y=5
if dataset['Location'].dtype=='object':
    x=dataset['Location'].nunique()
    if x<y:
        dataset=pd.get_dummies(dataset['Location'])
    else:
      print("Too many clases")
# Out:
# Too many clases

# %%
dataset['S2: Label g: Teacher Salary Growth'].nunique()
# Out:
# 3

# %%
y=5
if dataset['S2: Label g: Teacher Salary Growth'].dtype=='int64':
    x1=dataset['S2: Label g: Teacher Salary Growth'].nunique()
    if x1<y:
        dataset=pd.get_dummies(dataset,columns=['S2: Label g: Teacher Salary Growth'])
    else:
      print("Too many clases")

# %%
dataset.info()
dataset.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1577 entries, 0 to 1576
# Data columns (total 23 columns):
# Fiscal_Year                             1577 non-null int64
# Location                                1577 non-null object
# S1: Label a: FY14 Revised Base          1577 non-null int64
# S1: Label b: FSF & TL 09 C4E CTT        1577 non-null int64
# S1: Label c: FSF Over Formula           1577 non-null int64
# S2: Label d: FSF Preliminary            1577 non-null float64
# S2: Label a: FY14 Revised Base          1577 non-null int64
# S2: Label f: Register Change            1577 non-null float64
# S2: Label h: New School Foundation      1577 non-null int64
# S3: Label i: FY14 FSF at 100%           1577 non-null float64
# S3: Foundation                          1577 non-null int64
# S3: Label d - Foundation                1577 non-null float64
# S3: Label i - Foundation                1577 non-null float64
# S3: Label j: FSF Final%                 1577 non-null float64
# ...
